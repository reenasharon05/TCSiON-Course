# %% [markdown]
# <a href="https://colab.research.google.com/github/reenasharon05/TCSiON-Course/blob/main/12_10_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1ST TRIAL code
# ##session 8

# %%
import pandas as pd
#reading the dataset/retrieveing the dataset content
df=pd.read_csv("/content/gdpWorld.csv")

# %%
#to print/display the dataset
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
#shows the first 5 rows
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
#shows the last 5 rows
df.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
#to show the no of rows & columns in df
df.shape
# Out:
# (227, 20)

# %%
#no of total values
df.size
# Out:
# 4540

# %%
#to display the column name
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
#data types of each column
data.dtypes

#object=>string
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)             object
# Coastline (coast/area ratio)           object
# Net migration                          object
# Infant mortality (per 1000 births)     object
# GDP ($ per capita)                    float64
# Literacy (%)                           object
# Phones (per 1000)                      object
# Arable (%)                             object
# Crops (%)                              object
# Other (%)                              object
# Climate                                object
# Birthrate                              object
# Deathrate                              object
# Agriculture                            object
# Industry                               object
# Service                                object
# dtype: object

# %%
#how will u check whether duplicate reccord is there
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# Length: 227, dtype: bool

# %%
#how will u delete the duplicate datas
df.drop_duplicates()
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
#check whether there is any null value present in the column
df.isnull()   #NaN => NULL
# Out:
#      Country  Region  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      False   False       False           False                       False
# 1      False   False       False           False                       False
# 2      False   False       False           False                       False
# 3      False   False       False           False                       False
# 4      False   False       False           False                       False
# ..       ...     ...         ...             ...                         ...
# 222    False   False       False           False                       False
# 223    False   False       False           False                       False
# 224    False   False       False           False                       False
# 225    False   False       False           False                       False
# 226    False   False       False           False                       False
#
# ...

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
import seaborn as sns
#using heatmap we can show the null values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df[df['Country'].isin(['Afghanistan'])]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Population, Area (sq. mi.), Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita), Literacy (%), Phones (per 1000), Arable (%), Crops (%), Other (%), Climate, Birthrate, Deathrate, Agriculture, Industry, Service]
# Index: []

# %%
#to show records of particular string in any column
df[df['Country'].str.contains('Afghanistan')]
# Out:
#         Country                         Region  Population  Area (sq. mi.)  \
# 0  Afghanistan   ASIA (EX. NEAR EAST)             31056997          647500
#
#   Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# 0                       48,0                         0,00         23,06
#
#   Infant mortality (per 1000 births)  GDP ($ per capita) Literacy (%)  \
# 0                             163,07               700.0         36,0
#
#   Phones (per 1000) Arable (%) Crops (%) Other (%) Climate Birthrate  \
# 0               3,2      12,13      0,22     87,65       1      46,6
#
#   Deathrate Agriculture Industry Service
# 0     20,34        0,38     0,24    0,38

# %%
# number of rows and columns
df.values
# underlying numpy array — df are stored as numpy arrays for effeciencies.

# summarize (describe) the DataFrame
# describe all numeric columns
df.describe()

# describe all object columns
df.describe(include=['object'])

# describe all columns
df.describe(include='all')
# Out:
#              Country                               Region    Population  \
# count            227                                  227  2.270000e+02
# unique           227                                   11           NaN
# top     Afghanistan   SUB-SAHARAN AFRICA                            NaN
# freq               1                                   51           NaN
# mean             NaN                                  NaN  2.874028e+07
# std              NaN                                  NaN  1.178913e+08
# min              NaN                                  NaN  7.026000e+03
# 25%              NaN                                  NaN  4.376240e+05
# 50%              NaN                                  NaN  4.786994e+06
# 75%              NaN                                  NaN  1.749777e+07
# max              NaN                                  NaN  1.313974e+09
#
#         Area (sq. mi.) Pop. Density (per sq. mi.)  \
# count     2.270000e+02                        227
# ...

# %%
#conversely, if you want to transform a table into a hierarchical index, use the .stack() method
df.stack()
# Out:
# 0    Country                                        Afghanistan
#      Region                        ASIA (EX. NEAR EAST)
#      Population                                         31056997
#      Area (sq. mi.)                                       647500
#      Pop. Density (per sq. mi.)                             48,0
#                                                ...
# 226  Birthrate                                             28,01
#      Deathrate                                             21,84
#      Agriculture                                           0,179
#      Industry                                              0,243
#      Service                                               0,579
# Length: 4430, dtype: object

# %%
#how many regions are there
df.groupby('Region').Region.count()
# Out:
# Region
# ASIA (EX. NEAR EAST)                   28
# BALTICS                                 3
# C.W. OF IND. STATES                    12
# EASTERN EUROPE                         12
# LATIN AMER. & CARIB                    45
# NEAR EAST                              16
# NORTHERN AFRICA                         6
# NORTHERN AMERICA                        5
# OCEANIA                                21
# SUB-SAHARAN AFRICA                     51
# WESTERN EUROPE                         28
# Name: Region, dtype: int64

# %%
sns.countplot(df['GDP ($ per capita)'])
# Out:
# <Axes: ylabel='count'>
